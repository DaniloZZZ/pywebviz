# %%
import sys
sys.path.append('..')

# %%
from webvis import Vis
import numpy as np
import time
# %load_ext autoreload
# %autoreload 2

# %%
vis = Vis(ws_port=7700, vis_port=7000)
# Out:
# Starting ws server at localhost:7700
# Starting http at 7000
# Exception in thread Thread-4:
# trio.MultiError: Cancelled(), Cancelled(), <MultiError: Cancelled(), Cancelled(), Cancelled(), Cancelled()>
#
# Details of embedded exception 1:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#       yield scope
#     File "../webvis/ws_server.py", line 35, in ws_serve
#       await serve_websocket(server, addr, port, ssl_context=None)
#     File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#       await server.run(task_status=task_status)
#     File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#       await trio.sleep_forever()
#     File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#       raise combined_error_from_nursery
#     File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#       await trio.sleep_forever()
#     File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 51, in sleep_forever
#       await _core.wait_task_rescheduled(lambda _: _core.Abort.SUCCEEDED)
#     File "/usr/lib/python3.7/site-packages/trio/_core/_traps.py", line 166, in wait_task_rescheduled
#       return (await _async_yield(WaitTaskRescheduled(abort_func))).unwrap()
#     File "/usr/lib/python3.7/site-packages/outcome/_sync.py", line 111, in unwrap
#       raise captured_error
#     File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#       raise Cancelled._init()
#   trio.Cancelled
#
# Details of embedded exception 2:
#
#   Traceback (most recent call last):
#     File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#       yield scope
#     File "../webvis/ws_server.py", line 35, in ws_serve
#       await serve_websocket(server, addr, port, ssl_context=None)
#     File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#       await server.run(task_status=task_status)
#     File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#       await trio.sleep_forever()
#     File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#       raise combined_error_from_nursery
#     File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#       raise Cancelled._init()
#   trio.Cancelled
#
# Details of embedded exception 3:
#
#   trio.MultiError: Cancelled(), Cancelled(), Cancelled(), Cancelled()
#
#   Details of embedded exception 1:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#         yield scope
#       File "../webvis/ws_server.py", line 35, in ws_serve
#         await serve_websocket(server, addr, port, ssl_context=None)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#         await server.run(task_status=task_status)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#         await trio.sleep_forever()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 129, in serve_listeners
#         task_status.started(listeners)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
#   Details of embedded exception 2:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#         yield scope
#       File "../webvis/ws_server.py", line 35, in ws_serve
#         await serve_websocket(server, addr, port, ssl_context=None)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#         await server.run(task_status=task_status)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#         await trio.sleep_forever()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 129, in serve_listeners
#         task_status.started(listeners)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
#   Details of embedded exception 3:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 36, in _serve_one_listener
#         stream = await listener.accept()
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_socket.py", line 375, in accept
#         sock, _ = await self.socket.accept()
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 570, in accept
#         sock, addr = await self._accept()
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 315, in wrapper
#         return await self._nonblocking_helper(fn, args, kwargs, wait_fn)
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 552, in _nonblocking_helper
#         await wait_fn(self._sock)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_io_epoll.py", line 122, in wait_readable
#         await self._epoll_wait(fd, "read_task")
#       File "/usr/lib/python3.7/site-packages/trio/_core/_io_epoll.py", line 118, in _epoll_wait
#         await _core.wait_task_rescheduled(abort)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_traps.py", line 166, in wait_task_rescheduled
#         return (await _async_yield(WaitTaskRescheduled(abort_func))).unwrap()
#       File "/usr/lib/python3.7/site-packages/outcome/_sync.py", line 111, in unwrap
#         raise captured_error
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#         yield scope
#       File "../webvis/ws_server.py", line 35, in ws_serve
#         await serve_websocket(server, addr, port, ssl_context=None)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#         await server.run(task_status=task_status)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#         await trio.sleep_forever()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 129, in serve_listeners
#         task_status.started(listeners)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 50, in _serve_one_listener
#         handler_nursery.start_soon(_run_handler, stream, handler)
#       File "/usr/lib/python3.7/site-packages/trio/_abc.py", line 264, in __aexit__
#         await self.aclose()
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_socket.py", line 391, in aclose
#         await _core.checkpoint()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 1698, in checkpoint
#         await _core.wait_task_rescheduled(lambda _: _core.Abort.SUCCEEDED)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_traps.py", line 166, in wait_task_rescheduled
#         return (await _async_yield(WaitTaskRescheduled(abort_func))).unwrap()
#       File "/usr/lib/python3.7/site-packages/outcome/_sync.py", line 111, in unwrap
#         raise captured_error
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
#   Details of embedded exception 4:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 36, in _serve_one_listener
#         stream = await listener.accept()
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_socket.py", line 375, in accept
#         sock, _ = await self.socket.accept()
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 570, in accept
#         sock, addr = await self._accept()
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 315, in wrapper
#         return await self._nonblocking_helper(fn, args, kwargs, wait_fn)
#       File "/usr/lib/python3.7/site-packages/trio/_socket.py", line 552, in _nonblocking_helper
#         await wait_fn(self._sock)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_io_epoll.py", line 122, in wait_readable
#         await self._epoll_wait(fd, "read_task")
#       File "/usr/lib/python3.7/site-packages/trio/_core/_io_epoll.py", line 118, in _epoll_wait
#         await _core.wait_task_rescheduled(abort)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_traps.py", line 166, in wait_task_rescheduled
#         return (await _async_yield(WaitTaskRescheduled(abort_func))).unwrap()
#       File "/usr/lib/python3.7/site-packages/outcome/_sync.py", line 111, in unwrap
#         raise captured_error
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 116, in fail_at
#         yield scope
#       File "../webvis/ws_server.py", line 35, in ws_serve
#         await serve_websocket(server, addr, port, ssl_context=None)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 326, in serve_websocket
#         await server.run(task_status=task_status)
#       File "/usr/lib/python3.7/site-packages/trio_websocket/_impl.py", line 1096, in run
#         await trio.sleep_forever()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 129, in serve_listeners
#         task_status.started(listeners)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 506, in __aexit__
#         raise combined_error_from_nursery
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_serve_listeners.py", line 50, in _serve_one_listener
#         handler_nursery.start_soon(_run_handler, stream, handler)
#       File "/usr/lib/python3.7/site-packages/trio/_abc.py", line 264, in __aexit__
#         await self.aclose()
#       File "/usr/lib/python3.7/site-packages/trio/_highlevel_socket.py", line 391, in aclose
#         await _core.checkpoint()
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 1698, in checkpoint
#         await _core.wait_task_rescheduled(lambda _: _core.Abort.SUCCEEDED)
#       File "/usr/lib/python3.7/site-packages/trio/_core/_traps.py", line 166, in wait_task_rescheduled
#         return (await _async_yield(WaitTaskRescheduled(abort_func))).unwrap()
#       File "/usr/lib/python3.7/site-packages/outcome/_sync.py", line 111, in unwrap
#         raise captured_error
#       File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 740, in raise_cancel
#         raise Cancelled._init()
#     trio.Cancelled
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "../webvis/ws_server.py", line 40, in start_server
#     trio.run(ws_serve, addr, port, handler_func)
#   File "/usr/lib/python3.7/site-packages/trio/_core/_run.py", line 1444, in run
#     raise runner.main_task_outcome.error
#   File "../webvis/ws_server.py", line 35, in ws_serve
#     await serve_websocket(server, addr, port, ssl_context=None)
#   File "/usr/lib/python3.7/contextlib.py", line 130, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/lib/python3.7/site-packages/trio/_timeouts.py", line 118, in fail_at
#     raise TooSlowError
# trio.TooSlowError

# %%
for i in range(100):
    vis.vars['test']=np.sin(
        np.linspace(0+i/10,10+i/10,100)
    ).tolist()
    time.sleep(0.1)
#jkjkvis.vars['test']

# %%
# %%javascript
# $('#header').toggle();
# $('div#site').css("height","100%")

# %%
for i in range(100):
    vis.vars['undefined']=i
    time.sleep(0.1)
